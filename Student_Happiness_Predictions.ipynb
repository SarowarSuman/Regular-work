# %% [markdown]
# <a href="https://colab.research.google.com/github/SarowarSuman/Regular-work/blob/main/Student_Happiness_by_Suman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Studente_Happiness_Prediction.csv')

# %%
df
# Out:
#        Age             Gender Occupation Relationship Status  \
# 0    18-24               Male    Student              Broken
# 1    25-36  Prefer not to say    Student         Complicated
# 2    18-24             Female    Student              Broken
# 3    18-24               Male    Student   In a realtionship
# 4    18-24               Male    Student              Single
# ..     ...                ...        ...                 ...
# 980  18-24             Female    Student              Single
# 981  18-24               Male    Student              Single
# 982  18-24             Female    Student              Single
# 983  18-24             Female    Student              Single
# 984  18-24               Male    Student              Single
#
#              Education Level Physical Health?  \
# 0          Bachelor's degree             Good
# 1      Less than high school             Poor
# 2          Bachelor's degree             Fair
# ...

# %%
df.head()
# Out:
#      Age             Gender Occupation Relationship Status  \
# 0  18-24               Male    Student              Broken
# 1  25-36  Prefer not to say    Student         Complicated
# 2  18-24             Female    Student              Broken
# 3  18-24               Male    Student   In a realtionship
# 4  18-24               Male    Student              Single
#
#            Education Level Physical Health? Satisfied with Physical Fitness?  \
# 0        Bachelor's degree             Good                   Very Satisfied
# 1    Less than high school             Poor                   Very Satisfied
# 2        Bachelor's degree             Fair               Slightly Satisfied
# 3  High school diploma/GED             Good             Moderately Satisfied
# 4        Bachelor's degree             Fair               Slightly Satisfied
#
#     Close to others Mental Health Illnesses or Disabilities  ...  \
# 0      Occasionally          Good                        No  ...
# ...

# %%
df.shape
# Out:
# (985, 23)

# %%
new_column_names = {
    'Age': 'Age',
    'Gender': 'Gender',
    'Education (last/ongoing)': 'Education',
    'With whom do you live?': 'Living Situation',
    'What is your thinking about drug?': 'Attitude Towards Drugs',
    'With whom do you spend most of your times?': 'Social Connections',
    'Did you ever fail in your life?': 'Past Failures',
    'Do you get suicidal thoughts?': 'Suicidal Thoughts',
    'How is your family relationship?': 'Family Relationships',
    'What is the financial condition of your family?': 'Family Finances',
    'How many addicted friends do you have?': 'Addicted Friends',
    'Do you have any addicted person in your family?': 'Family Addiction',
    'Are you satisfied with your workplace?': 'Workplace Satisfaction',
    'Where do you think you could make changes to increase your happiness levels?': 'happiness',
    'Do you live with any drug user?': 'Living with Drug User',
    'What can be the factors for using drug?': 'Drug Use Factors',
    'How satisfied are you with your current job or occupation?': 'current job',
    'What is the name of the drug you used for the 1st time?': 'First Drug Name',
    'Self-esteem and Self-confidence': 'self-confidence',
    'How often do you use drugs?': 'Frequency of Drug Use',
    'During which year do you feel you experienced the highest level of Happiness?': 'year',
    'In what occasions do you use drugs?': 'Occasions for Drug Use',
    'If you have a chance, will you taste drug?': 'Willingness to Try Drugs',
    'Is it easy to control the use of drug?': 'Drug Control',
    'Why did you start using drugs?': 'Reasons for Starting',
    'Do you feel guilty after taking drugs?': 'Guilt After Drug Use'
}

df.rename(columns=new_column_names, inplace=True)

df.head()
# Out:
#      Age             Gender Occupation Relationship Status  \
# 0  18-24               Male    Student              Broken
# 1  25-36  Prefer not to say    Student         Complicated
# 2  18-24             Female    Student              Broken
# 3  18-24               Male    Student   In a realtionship
# 4  18-24               Male    Student              Single
#
#            Education Level Physical Health? Satisfied with Physical Fitness?  \
# 0        Bachelor's degree             Good                   Very Satisfied
# 1    Less than high school             Poor                   Very Satisfied
# 2        Bachelor's degree             Fair               Slightly Satisfied
# 3  High school diploma/GED             Good             Moderately Satisfied
# 4        Bachelor's degree             Fair               Slightly Satisfied
#
#     Close to others Mental Health Illnesses or Disabilities  ...  \
# 0      Occasionally          Good                        No  ...
# ...

# %%
df.isnull().sum()
# Out:
# Age                                                                                                   0
# Gender                                                                                                0
# Occupation                                                                                            0
# Relationship Status                                                                                   0
# Education Level                                                                                       0
# Physical Health?                                                                                      0
# Satisfied with Physical Fitness?                                                                      0
# Close to others                                                                                       0
# Mental Health                                                                                         0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
import math
modeTestScore14=(df['happiness'].mode()[0])
modeTestScore17=(df['current job'].mode()[0])
modeTestScore19=(df['self-confidence'].mode()[0])
modeTestScore21=(df['year'].mode()[0])


df['happiness']=df['happiness'].fillna(modeTestScore14)
df['current job']=df['current job'].fillna(modeTestScore17)
df['self-confidence']=df['self-confidence'].fillna(modeTestScore19)
df['year']=df['year'].fillna(modeTestScore21)

# %%
df.isnull().sum()
# Out:
# Age                                                                                                  0
# Gender                                                                                               0
# Occupation                                                                                           0
# Relationship Status                                                                                  0
# Education Level                                                                                      0
# Physical Health?                                                                                     0
# Satisfied with Physical Fitness?                                                                     0
# Close to others                                                                                      0
# Mental Health                                                                                        0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

categorical_columns = [
    'Age',
    'Gender',
    'Occupation',
    'Relationship Status',
    'Education Level',
    'Physical Health?',
    'Satisfied with Physical Fitness?',
    'Close to others',
    'Mental Health',
    'Illnesses or Disabilities',
    'Relationships with Family Members',
    'Relationships with Friends',
    'What part of your life do you think could bring you more joy and satisfaction?',
    'happiness',
    'Social Support Network',
    'How often do you feel happy in a typical week?',
    'current job', # Corrected from 'How satisfied are you with your current job or occupation?'
    'Achievement of Personal Goals',
    'self-confidence', # Corrected from 'Self-esteem and Self-confidence'
    'Tpical social style?',
    'year', # Corrected from 'During which year do you feel you experienced the highest level of Happiness?'
    'During which year do you feel you experienced the most difficult times or lowest Emotional State?',
    'How happy do you usually consider yourself?',
]

for column in categorical_columns:
    df[column] = df[column].astype(str)
    df[column] = label_encoder.fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 23 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Age                                                                                                985 non-null    int64
#  1   Gender                                                                                             985 non-null    int64
#  2   Occupation                                                                                         985 non-null    int64
#  3   Relationship Status                                                                                985 non-null    int64
# ...

# %%
df.describe()
# Out:
#               Age      Gender  Occupation  Relationship Status  \
# count  985.000000  985.000000  985.000000           985.000000
# mean     0.178680    0.521827    2.924873             3.165482
# std      0.496484    0.505841    0.498413             1.208047
# min      0.000000    0.000000    0.000000             0.000000
# 25%      0.000000    0.000000    3.000000             2.000000
# 50%      0.000000    1.000000    3.000000             4.000000
# 75%      0.000000    1.000000    3.000000             4.000000
# max      2.000000    2.000000    4.000000             4.000000
#
#        Education Level  Physical Health?  Satisfied with Physical Fitness?  \
# count       985.000000        985.000000                        985.000000
# mean          0.740102          1.848731                          2.105584
# std           1.162361          0.880261                          1.167401
# min           0.000000          0.000000                          0.000000
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, orient='h')
plt.title("Box Plot of DataFrame")
plt.show()

# %%
# prompt: drop timestamp

# The 'Timestamp' column does not exist, so this line will be commented out or removed to prevent an error.
# df.drop(columns=["Timestamp"], inplace=True)

# %%
df.corr()
# Out:
#                                                          Age    Gender  \
# Age                                                 1.000000  0.033013
# Gender                                              0.033013  1.000000
# Occupation                                         -0.052476 -0.066045
# Relationship Status                                -0.117125 -0.074934
# Education Level                                     0.372877  0.135833
# Physical Health?                                   -0.084588  0.065622
# Satisfied with Physical Fitness?                    0.100675  0.064932
# Close to others                                     0.118409  0.083027
# Mental Health                                      -0.082945 -0.000483
# Illnesses or Disabilities                           0.103305 -0.000366
# Relationships with Family Members                  -0.012909 -0.101567
# Relationships with Friends                          0.029410 -0.145345
# ...

# %%
plt.figure(figsize=(18,15))
sns.heatmap(df.corr(), annot=True,fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# # **Data Spliting**

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = df.select_dtypes(include=['object']).columns

encoder = LabelEncoder()
for col in categorical_columns:
    df[col] = encoder.fit_transform(df[col])

X_numeric = df[numeric_columns].drop(columns=['Relationships with Family Members'])
y = df['Relationships with Family Members']

selector = SelectKBest(score_func=chi2, k=5)

X_numeric_new = selector.fit_transform(X_numeric, y)

selected_indices = selector.get_support(indices=True)

selected_features = X_numeric.columns[selected_indices]
print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['Age', 'Education Level', 'Close to others',
#        'What part of your life do you think could bring you more joy and satisfaction?',
#        'How often do you feel happy in a typical week?'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['Age', 'Gender', 'Occupation', 'Relationship Status', 'Education Level', 'Physical Health?', 'Satisfied with Physical Fitness?', 'Close to others', 'Mental Health', 'Illnesses or Disabilities', 'Relationships with Family Members', 'Relationships with Friends', 'What part of your life do you think could bring you more joy and satisfaction?', 'happiness', 'Social Support Network', 'How often do you feel happy in a typical week?', 'current job', 'Achievement of Personal Goals', 'self-confidence', 'Tpical social style?', 'year', 'During which year do you feel you experienced the most difficult times or lowest Emotional State?', 'How happy do you usually consider yourself?']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

print("Training data shape (X_train, y_train):", X_train.shape, y_train.shape)
print("Testing data shape (X_test, y_test):", X_test.shape, y_test.shape)
# Out:
# Training data shape (X_train, y_train): (788, 5) (788,)
# Testing data shape (X_test, y_test): (197, 5) (197,)

# %% [markdown]
# # **Naive Bayes Model**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.48223350253807107

# %%
from sklearn.metrics import confusion_matrix
cm = np.array(pd.crosstab(y_test, y_pred))
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Naive Bayes Classifier")
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.40      0.48        83
#            1       0.00      0.00      0.00        12
#            2       0.48      0.69      0.57        88
#            3       0.10      0.07      0.08        14
#
#     accuracy                           0.48       197
#    macro avg       0.30      0.29      0.28       197
# weighted avg       0.48      0.48      0.46       197

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.817258883248731
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86        83
#            1       0.47      0.67      0.55        12
#            2       0.84      0.86      0.85        88
#            3       0.83      0.36      0.50        14
#
#     accuracy                           0.82       197
#    macro avg       0.75      0.69      0.69       197
# weighted avg       0.83      0.82      0.81       197

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Decision Tree Classifier")
plt.show()

# %% [markdown]
# # Till Confusion Matrix. Done by Sarowar Mahfuz Suman,    **ID:1345**
